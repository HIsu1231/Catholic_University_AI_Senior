# %% [markdown]
# <a href="https://colab.research.google.com/github/HIsu1231/Catholic_University_AI_Senior/blob/main/AI%EC%84%A0%EB%B0%B0_DecisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #전체학년대상

# %% [markdown]
# ##96년~

# %%
#df3는 년도 없음, 학기인덱스 없음
df3 = df[['제1전공코드', '제2전공코드', '입학구분', '입학전형구분','성별', '신청학점', '이수학점', '평균평점',
           '동아리', '장학금', '봉사활동시간', '학술활동', '교환학생(기간)', '전공성적평균','교양성적평균', '기타성적평균', 'label',
           '학부/과코드', '공통_영어평균', '공통_종교평균', '공통_팀플평균', '공통_봉사평균',
           '공통_1학년과목평균', '출신고교인덱스', '출신고교지역인덱스']]

# %%
X_data = df3.drop('label', axis=1)
y_data = df3['label']
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=7)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (252131, 24) (252131,) (108057, 24) (108057,)

# %%
tree=DecisionTreeClassifier(criterion='gini', class_weight={0:1, 1:10})
model=tree.fit(X_train, y_train)

# %%
from sklearn import metrics
y_pred = model.predict(X_test)
print('정확도:',metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))#, average='macro'))
print('recall:', metrics.recall_score(y_test, y_pred))#, average='macro'))
print('f1_score:', metrics.f1_score(y_test, y_pred))#, average='macro'))
# Out:
# 정확도: 0.9494896212184311
# precision: 0.22544583444237423
# recall: 0.24948453608247423
# f1_score: 0.23685682326621926

# %%
s = str(list(set(df3['label'].values)))
c = str(list(set(df3.columns)))
print(c)
# Out:
# ['label', '이수학점', '교양성적평균', '공통_팀플평균', '제2전공코드', '입학전형구분', '평균평점', '제1전공코드', '전공성적평균', '출신고교지역인덱스', '봉사활동시간', '입학구분', '장학금', '공통_1학년과목평균', '출신고교인덱스', '동아리', '공통_종교평균', '공통_영어평균', '학술활동', '기타성적평균', '학부/과코드', '교환학생(기간)', '신청학점', '공통_봉사평균', '성별']

# %%
#가장 영항 많이 끼친 feature 뽑기
import matplotlib.pyplot as plt
importance = pd.Series(model.feature_importances_, X_test.columns)
print(importance)
# Out:
# 제1전공코드        0.093563
# 제2전공코드        0.092575
# 입학구분          0.006483
# 입학전형구분        0.039361
# 성별            0.017325
# 신청학점          0.039557
# 이수학점          0.035389
# 평균평점          0.105849
# 동아리           0.014317
# 장학금           0.018148
# 봉사활동시간        0.009883
# 학술활동          0.004190
# 교환학생(기간)      0.000306
# 전공성적평균        0.055879
# 교양성적평균        0.073682
# 기타성적평균        0.015483
# 학부/과코드        0.051229
# 공통_영어평균       0.019611
# 공통_종교평균       0.008686
# 공통_팀플평균       0.016171
# 공통_봉사평균       0.001340
# 공통_1학년과목평균    0.065364
# 출신고교인덱스       0.163652
# 출신고교지역인덱스     0.051957
# dtype: float64

# %% [markdown]
# ##12년~

# %%
df2 = df[['제1전공코드', '제2전공코드', '입학구분', '입학전형구분','성별', '신청학점', '이수학점', '평균평점',
           '동아리', '장학금', '봉사활동시간', '학술활동', '교환학생(기간)', '전공성적평균','교양성적평균', '기타성적평균', 'label',
           '학부/과코드', '공통_영어평균', '공통_종교평균', '공통_팀플평균', '공통_봉사평균',
           '공통_1학년과목평균', '출신고교인덱스', '출신고교지역인덱스', '년도']]

# %%
#년도가 2012년 이후인 데이터만 사용
l = []
for i in range(len(df2)):
  if df2['년도'][i] >= 2012:
      l.append(i)

# %%
df3 = df2.loc[l, :]
df3.reset_index(inplace=True) #index reset하기 - 기존 객체 변경 ㅇ

# %%
df3
# Out:
#          index     제1전공코드     제2전공코드  입학구분  입학전형구분  성별  신청학점  이수학점  평균평점  동아리  \
# 0         1566  240000035  240000004     1       8   2    16    16  0.00    0
# 1         3634  240000041  240000048     0      15   1    16    16  2.22    0
# 2         3720  240000014  240000197     0       8   2     6     6  2.25    0
# 3         3721  240000014  240000197     0       8   2     6     6  3.25    0
# 4         3722  240000014  240000197     0       8   2     3     3  2.00    0
# ...        ...        ...        ...   ...     ...  ..   ...   ...   ...  ...
# 162597  360183  230000358  220000416     0      10   1    18    18  3.22    0
# 162598  360184  230000350  240000004     0      11   1    16    16  1.31    1
# 162599  360185  230000350  240000004     0      11   1    18     5  0.44    1
# 162600  360186  230000365  666666666     0      11   2    20    20  4.08    0
# 162601  360187  230000365  666666666     0      11   2    20    20  4.16    0
#
# ...

# %%
set(df3['년도'].values)
# Out:
# {2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021}

# %%
df4 = df3[['제1전공코드', '제2전공코드', '입학구분', '입학전형구분','성별', '신청학점', '이수학점', '평균평점',
           '동아리', '장학금', '봉사활동시간', '학술활동', '교환학생(기간)', '전공성적평균','교양성적평균', '기타성적평균', 'label',
           '학부/과코드', '공통_영어평균', '공통_종교평균', '공통_팀플평균', '공통_봉사평균',
           '공통_1학년과목평균', '출신고교인덱스', '출신고교지역인덱스']]

# %%
X_data = df4.drop('label', axis=1) #label 제거해서 사용
y_data = df4['label']
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=7)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (113821, 24) (113821,) (48781, 24) (48781,)

# %%
tree=DecisionTreeClassifier(criterion='gini', class_weight={0:1, 1:10}) #사용할 모델
model=tree.fit(X_train, y_train)

# %%
from sklearn import metrics
y_pred = model.predict(X_test)
print('정확도:',metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))#, average='macro')) #, average='weighted', labels=np.unique(y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))#, average='macro')) #, average='weighted', labels=np.unique(y_pred))
print('f1_score:', metrics.f1_score(y_test, y_pred))#, average='macro')) #, average='weighted', labels=np.unique(y_pred))
# Out:
# 정확도: 0.9606199134909084
# precision: 0.25666906993511174
# recall: 0.2857142857142857
# f1_score: 0.27041397645271553

# %%
import matplotlib.pyplot as plt
importance = pd.Series(model.feature_importances_, X_test.columns)
print(importance)
# Out:
# 제1전공코드        0.076821
# 제2전공코드        0.182277
# 입학구분          0.002385
# 입학전형구분        0.039880
# 성별            0.014598
# 신청학점          0.041968
# 이수학점          0.029251
# 평균평점          0.072123
# 동아리           0.035329
# 장학금           0.020013
# 봉사활동시간        0.010313
# 학술활동          0.005876
# 교환학생(기간)      0.000301
# 전공성적평균        0.057940
# 교양성적평균        0.063203
# 기타성적평균        0.011588
# 학부/과코드        0.032568
# 공통_영어평균       0.011004
# 공통_종교평균       0.011824
# 공통_팀플평균       0.041743
# 공통_봉사평균       0.001716
# 공통_1학년과목평균    0.023511
# 출신고교인덱스       0.161924
# 출신고교지역인덱스     0.051846
# dtype: float64

# %% [markdown]
# ##17년~

# %%
l = []
for i in range(len(df2)):
  if df2['년도'][i] >= 2017:
      l.append(i)

# %%
df3 = df2.loc[l, :]
df3.reset_index(inplace=True)

# %%
df3
# Out:
#         index     제1전공코드     제2전공코드  입학구분  입학전형구분  성별  신청학점  이수학점  평균평점  동아리  \
# 0        3884  240000107  240000105     0       8   2    16    16  0.00    0
# 1        4260  240000195  240000004     0       0   2    16    16  0.00    0
# 2        6444  240000107  240000023     0       8   2    16    16  0.00    0
# 3       15062  240000041  240000048     0       0   1    16    16  0.00    0
# 4       18517  230000338  230000359     1       1   2    19    19  3.79    1
# ...       ...        ...        ...   ...     ...  ..   ...   ...   ...  ...
# 77762  360183  230000358  220000416     0      10   1    18    18  3.22    0
# 77763  360184  230000350  240000004     0      11   1    16    16  1.31    1
# 77764  360185  230000350  240000004     0      11   1    18     5  0.44    1
# 77765  360186  230000365  666666666     0      11   2    20    20  4.08    0
# 77766  360187  230000365  666666666     0      11   2    20    20  4.16    0
#
# ...

# %%
set(df3['년도'].values)
# Out:
# {2017, 2018, 2019, 2020, 2021}

# %%
df4 = df3[['제1전공코드', '제2전공코드', '입학구분', '입학전형구분','성별', '신청학점', '이수학점', '평균평점',
           '동아리', '장학금', '봉사활동시간', '학술활동', '교환학생(기간)', '전공성적평균','교양성적평균', '기타성적평균', 'label',
           '학부/과코드', '공통_영어평균', '공통_종교평균', '공통_팀플평균', '공통_봉사평균',
           '공통_1학년과목평균', '출신고교인덱스', '출신고교지역인덱스']]

# %%
X_data = df4.drop('label', axis=1)
y_data = df4['label']
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=7)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (54436, 24) (54436,) (23331, 24) (23331,)

# %%
tree=DecisionTreeClassifier(criterion='gini', class_weight={0:1, 1:10})
model=tree.fit(X_train, y_train)

# %%
#feature_importance = pd.DataFrame(tree.feature_importances_.reshape((1, -1)), columns=X_data.columns, index=['feature_importance'])
#feature_importance.to_csv('./feature_importance_2.csv', encoding='utf-8-sig')
#dict(feature_importance)

# %%
from sklearn import metrics
y_pred = model.predict(X_test)
print('정확도:',metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))#, average='macro'))
print('recall:', metrics.recall_score(y_test, y_pred))#, average='macro'))
print('f1_score:', metrics.f1_score(y_test, y_pred))#, average='macro'))
# Out:
# 정확도: 0.9668252539539668
# precision: 0.32295081967213113
# recall: 0.35304659498207885
# f1_score: 0.33732876712328763

# %%
s = list(str(set(df3['label'].values)))
c = list(str(set(df3.columns)))

# %%
import matplotlib.pyplot as plt
importance = pd.Series(model.feature_importances_, X_test.columns)
print(importance)
# Out:
# 제1전공코드        0.054004
# 제2전공코드        0.204873
# 입학구분          0.000927
# 입학전형구분        0.036959
# 성별            0.009813
# 신청학점          0.034148
# 이수학점          0.026343
# 평균평점          0.060189
# 동아리           0.028984
# 장학금           0.026110
# 봉사활동시간        0.008935
# 학술활동          0.002005
# 교환학생(기간)      0.000000
# 전공성적평균        0.054755
# 교양성적평균        0.063308
# 기타성적평균        0.013795
# 학부/과코드        0.089001
# 공통_영어평균       0.008126
# 공통_종교평균       0.013883
# 공통_팀플평균       0.043672
# 공통_봉사평균       0.001416
# 공통_1학년과목평균    0.030135
# 출신고교인덱스       0.145258
# 출신고교지역인덱스     0.043359
# dtype: float64

# %%
#plot_tree(model, class_names=s, feature_names=c, impurity=True, filled=True, rounded=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-240-eaa593bdf92f> in <module>()
# ----> 1 plot_tree(model, class_names=s, feature_names=c, impurity=True, filled=True, rounded=True)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     193         fontsize=fontsize,
#     194     )
# --> 195     return exporter.export(decision_tree, ax=ax)
#     196
#     197
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_export.py in export(self, decision_tree, ax)
#     667         scale_x = ax_width / max_x
#     668         scale_y = ax_height / max_y
# --> 669         self.recurse(draw_tree, decision_tree.tree_, ax, max_x, max_y)
#     670
# ...

# %% [markdown]
# #1학년대상

# %%
df2 = df[['제1전공코드', '제2전공코드', '입학구분', '입학전형구분','성별', '신청학점', '이수학점', '평균평점',
           '동아리', '장학금', '봉사활동시간', '학술활동', '교환학생(기간)', '전공성적평균','교양성적평균', '기타성적평균', 'label',
           '학부/과코드', '공통_영어평균', '공통_종교평균', '공통_팀플평균', '공통_봉사평균',
           '공통_1학년과목평균', '출신고교인덱스', '출신고교지역인덱스', '년도', '입학년도', '학기인덱스']]

# %%
#년도랑 입학년도가 같은 시점만 빼면 전체 학생의 1학년때 정보가 나옴
l = []
for i in range(len(df2)):
  if df2['년도'][i] == df2['입학년도'][i]:
    if (df2['학기인덱스'][i] == 12) or (df2['학기인덱스'][i] == 9):
      l.append(i)

df3 = df2.loc[l, :]
df3 #일학년때 정보들이 다 들어있는 df
df3.reset_index(inplace=True)

# %% [markdown]
# ##96년~

# %%
df4 = df3[['제1전공코드', '제2전공코드', '입학구분', '입학전형구분','성별', '신청학점', '이수학점', '평균평점',
           '동아리', '장학금', '봉사활동시간', '학술활동', '교환학생(기간)', '전공성적평균','교양성적평균', '기타성적평균', 'label',
           '학부/과코드', '공통_영어평균', '공통_종교평균', '공통_팀플평균', '공통_봉사평균',
           '공통_1학년과목평균', '출신고교인덱스', '출신고교지역인덱스']]

# %%
df4
# Out:
#           제1전공코드     제2전공코드  입학구분  입학전형구분  성별  신청학점  이수학점  평균평점  동아리  장학금  \
# 0      240000039  240000004     1       8   1    19    19  2.95    0    0
# 1      240000039  240000004     1       8   1    18    18  3.17    0    1
# 2      240000012  240000004     1       8   2    17    17  4.12    0    0
# 3      240000012  240000004     1       8   2    16    16  4.00    0    0
# 4      240000013  666666666     1       8   2    11    11  2.86    0    0
# ...          ...        ...   ...     ...  ..   ...   ...   ...  ...  ...
# 88740  230000358  220000416     0      10   1    15    15  4.13    0    2
# 88741  230000358  220000416     0      10   1    18    18  3.22    0    2
# 88742  230000350  240000004     0      11   1    16    16  1.31    1    2
# 88743  230000365  666666666     0      11   2    20    20  4.08    0    0
# 88744  230000365  666666666     0      11   2    20    20  4.16    0    0
#
#        ...  기타성적평균  label     학부/과코드  공통_영어평균  공통_종교평균  공통_팀플평균  공통_봉사평균  \
# ...

# %%
from sklearn.model_selection import train_test_split

X_data = df4.drop('label', axis=1)
y_data = df4['label']
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=7)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (62121, 24) (62121,) (26624, 24) (26624,)

# %%
tree=DecisionTreeClassifier(criterion='gini', class_weight={0:1, 1:10})
model=tree.fit(X_train, y_train)

# %%
from sklearn import metrics
y_pred = model.predict(X_test)
print('정확도:',metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))#, average='macro'))
print('recall:', metrics.recall_score(y_test, y_pred))#, average='macro'))
print('f1_score:', metrics.f1_score(y_test, y_pred))#, average='macro'))
# Out:
# 정확도: 0.9062124399038461
# precision: 0.31721890277023357
# recall: 0.3201754385964912
# f1_score: 0.3186903137789905

# %%
print(sum(y_pred))
# Out:
# 1809

# %%
import matplotlib.pyplot as plt
importance = pd.Series(model.feature_importances_, X_test.columns)
print(importance)
# Out:
# 제1전공코드        0.142534
# 제2전공코드        0.093426
# 입학구분          0.019642
# 입학전형구분        0.036939
# 성별            0.013805
# 신청학점          0.040973
# 이수학점          0.022733
# 평균평점          0.104113
# 동아리           0.016993
# 장학금           0.019073
# 봉사활동시간        0.005989
# 학술활동          0.003020
# 교환학생(기간)      0.000000
# 전공성적평균        0.045406
# 교양성적평균        0.090882
# 기타성적평균        0.005775
# 학부/과코드        0.059575
# 공통_영어평균       0.028308
# 공통_종교평균       0.000346
# 공통_팀플평균       0.020488
# 공통_봉사평균       0.000037
# 공통_1학년과목평균    0.031600
# 출신고교인덱스       0.154288
# 출신고교지역인덱스     0.044056
# dtype: float64

# %% [markdown]
# ##12년~

# %%
l = []
for i in range(len(df3)):
  if df3['년도'][i] >= 2012:
      l.append(i)

# %%
df4 = df3.loc[l, :]
df4
df4.reset_index(inplace=True)

# %%
df4
# Out:
#        level_0   index     제1전공코드     제2전공코드  입학구분  입학전형구분  성별  신청학점  이수학점  \
# 0         4633   18521  230000338  230000359     1       1   2    18    18
# 1        44428  192928  230000372  230000343     0       6   1    12    12
# 2        44429  192929  230000372  230000343     0       6   1    18    18
# 3        44653  194041  230000338  230000350     0       2   1    13    13
# 4        44654  194042  230000338  230000350     0       2   1     9     5
# ...        ...     ...        ...        ...   ...     ...  ..   ...   ...
# 34780    88740  360182  230000358  220000416     0      10   1    15    15
# 34781    88741  360183  230000358  220000416     0      10   1    18    18
# 34782    88742  360184  230000350  240000004     0      11   1    16    16
# 34783    88743  360186  230000365  666666666     0      11   2    20    20
# 34784    88744  360187  230000365  666666666     0      11   2    20    20
#
# ...

# %%
set(df4['년도'].values)
# Out:
# {2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021}

# %%
df5 = df4[['제1전공코드', '제2전공코드', '입학구분', '입학전형구분','성별', '신청학점', '이수학점', '평균평점',
           '동아리', '장학금', '봉사활동시간', '학술활동', '교환학생(기간)', '전공성적평균','교양성적평균', '기타성적평균', 'label',
           '학부/과코드', '공통_영어평균', '공통_종교평균', '공통_팀플평균', '공통_봉사평균',
           '공통_1학년과목평균', '출신고교인덱스', '출신고교지역인덱스']]

# %%
X_data = df5.drop('label', axis=1)
y_data = df5['label']
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=7)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (24349, 24) (24349,) (10436, 24) (10436,)

# %%
tree=DecisionTreeClassifier(criterion='gini', class_weight={0:1, 1:10})
model=tree.fit(X_train, y_train)

# %%
from sklearn import metrics
y_pred = model.predict(X_test)
print('정확도:',metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))#, average='macro'))
print('recall:', metrics.recall_score(y_test, y_pred))#, average='macro'))
print('f1_score:', metrics.f1_score(y_test, y_pred))#, average='macro'))
# Out:
# 정확도: 0.9179762361057877
# precision: 0.3909985935302391
# recall: 0.39657631954350925
# f1_score: 0.3937677053824362

# %%
#s = set(df4['label'].values)
#c = set(df4.colums)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-384-21e5fb454124> in <module>()
#       1 s = set(df4['label'].values)
# ----> 2 c = set(df4.colums)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
#plot_tree(model, class_names=s, feature_names=c, impurity=True, filled=True, rounded=True)

# %%
import matplotlib.pyplot as plt
importance = pd.Series(model.feature_importances_, X_test.columns)
print(importance)
# Out:
# 제1전공코드        0.103828
# 제2전공코드        0.239050
# 입학구분          0.026838
# 입학전형구분        0.027556
# 성별            0.011001
# 신청학점          0.027070
# 이수학점          0.023200
# 평균평점          0.075852
# 동아리           0.043367
# 장학금           0.025728
# 봉사활동시간        0.003101
# 학술활동          0.010337
# 교환학생(기간)      0.000000
# 전공성적평균        0.042566
# 교양성적평균        0.067274
# 기타성적평균        0.002363
# 학부/과코드        0.024072
# 공통_영어평균       0.015837
# 공통_종교평균       0.002469
# 공통_팀플평균       0.026182
# 공통_봉사평균       0.000946
# 공통_1학년과목평균    0.023957
# 출신고교인덱스       0.130258
# 출신고교지역인덱스     0.047147
# dtype: float64

# %% [markdown]
# ##17년~

# %%
l = []
for i in range(len(df3)):
  if df3['년도'][i] >= 2017:
      l.append(i)

# %%
df4 = df3.loc[l, :]
df4
df4.reset_index(inplace=True)

# %%
df4
# Out:
#        level_0   index      학생구분번호    년도   학기    생년  성별      학부/과코드  \
# 0         4633   18521  M000000001  2020  1학기  1997   2  M220000324
# 1        65156  287295  M000056234  2017  2학기  1998   1  M220000326
# 2        65274  287833  M000056308  2017  2학기  1995   2  M220000328
# 3        65275  287840  M000056309  2017  2학기  1996   1  M220000330
# 4        67416  296981  M000057527  2017  2학기  1999   2  M220000331
# ...        ...     ...         ...   ...  ...   ...  ..         ...
# 16973    88740  360182  M000064917  2019  1학기  1999   1  M220000330
# 16974    88741  360183  M000064917  2019  2학기  1999   1  M220000330
# 16975    88742  360184  M000059584  2017  1학기  1999   1  M220000328
# 16976    88743  360186  M000068327  2021  1학기  2001   2  M220000332
# 16977    88744  360187  M000068327  2021  2학기  2001   2  M220000332
#
#            제1전공코드      제2전공코드  ...    교양성적평균    기타성적평균  label 학부/과인덱스 제1전공인덱스  \
# ...

# %%
set(df4['년도'].values)
# Out:
# {2017, 2018, 2019, 2020, 2021}

# %%
df5 = df4[['제1전공코드', '제2전공코드', '입학구분', '입학전형구분','성별', '신청학점', '이수학점', '평균평점',
           '동아리', '장학금', '봉사활동시간', '학술활동', '교환학생(기간)', '전공성적평균','교양성적평균', '기타성적평균', 'label',
           '학부/과코드', '공통_영어평균', '공통_종교평균', '공통_팀플평균', '공통_봉사평균',
           '공통_1학년과목평균', '출신고교인덱스', '출신고교지역인덱스']]

# %%
X_data = df5.drop('label', axis=1)
y_data = df5['label']
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=7)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (11884, 24) (11884,) (5094, 24) (5094,)

# %%
tree=DecisionTreeClassifier(criterion='gini', class_weight={0:1, 1:10})

model=tree.fit(X_train, y_train)

# %%
from sklearn import metrics
y_pred = model.predict(X_test)
print('정확도:',metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))#, average='macro'))
print('recall:', metrics.recall_score(y_test, y_pred))#, average='macro'))
print('f1_score:', metrics.f1_score(y_test, y_pred))#, average='macro'))
# Out:
# 정확도: 0.9379662347860228
# precision: 0.49193548387096775
# recall: 0.5903225806451613
# f1_score: 0.5366568914956013

# %%
#s = set(df4['label'].values)
#c = set(df4.colums)

# %%
#plot_tree(model, class_names=s, feature_names=c, impurity=True, filled=True, rounded=True)

# %%
import matplotlib.pyplot as plt
importance = pd.Series(model.feature_importances_, X_test.columns)
print(importance)
# Out:
# 제1전공코드        0.326524
# 제2전공코드        0.064799
# 입학구분          0.051152
# 입학전형구분        0.023757
# 성별            0.015578
# 신청학점          0.031759
# 이수학점          0.019250
# 평균평점          0.063851
# 동아리           0.024512
# 장학금           0.020701
# 봉사활동시간        0.003448
# 학술활동          0.001796
# 교환학생(기간)      0.000000
# 전공성적평균        0.033476
# 교양성적평균        0.059318
# 기타성적평균        0.003147
# 학부/과코드        0.026140
# 공통_영어평균       0.014288
# 공통_종교평균       0.000392
# 공통_팀플평균       0.033118
# 공통_봉사평균       0.001326
# 공통_1학년과목평균    0.022517
# 출신고교인덱스       0.115480
# 출신고교지역인덱스     0.043671
# dtype: float64
